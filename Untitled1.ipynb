# %%
#Pandas Data Reader - How to get Yahoo Stock Data
import pandas as pd
import numpy as np
import pandas_datareader as dr
# %matplotlib inline

# %%
df = dr.data.get_data_yahoo('ibm', start='2018-09-27', end='2019-11-23')
df
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2018-09-27  152.389999  151.160004  152.009995  151.500000  3477600.0
# 2018-09-28  151.630005  150.789993  151.160004  151.210007  3305800.0
# 2018-10-01  153.419998  151.710007  151.710007  153.000000  3757400.0
# 2018-10-02  153.839996  152.500000  152.990005  153.750000  3029900.0
# 2018-10-03  154.360001  152.800003  154.000000  153.220001  3315300.0
# ...                ...         ...         ...         ...        ...
# 2019-11-18  134.479996  133.229996  134.300003  134.309998  3210400.0
# 2019-11-19  135.380005  134.460007  134.880005  134.520004  2995000.0
# 2019-11-20  134.460007  132.750000  134.059998  133.199997  4138200.0
# 2019-11-21  134.169998  132.979996  133.399994  133.839996  3345300.0
# 2019-11-22  134.649994  133.589996  134.190002  134.339996  3297500.0
#
#              Adj Close
# Date
# 2018-09-27  142.748138
# 2018-09-28  142.474899
# 2018-10-01  144.161469
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 292 entries, 2018-09-27 to 2019-11-22
# Data columns (total 6 columns):
# High         292 non-null float64
# Low          292 non-null float64
# Open         292 non-null float64
# Close        292 non-null float64
# Volume       292 non-null float64
# Adj Close    292 non-null float64
# dtypes: float64(6)
# memory usage: 16.0 KB

# %%
df[['Open', 'Close']].plot(figsize=(15,5));
